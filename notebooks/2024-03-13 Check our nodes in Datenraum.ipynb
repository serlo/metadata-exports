# %% [markdown]
# # Load all nodes of Serlo from Datenraum

# %%
from getpass import getpass

CLIENT_ID = getpass("CLIENT_ID: ")
CLIENT_SECRET = getpass("CLIENT_SECRET: ")
# Out:
# CLIENT_ID: ········
# CLIENT_SECRET: ········

# %%
import sys
import os

sys.path.append(os.path.join(os.getcwd(), '..'))

from datenraum import *

BASE_URL = "https://dam.demo.meinbildungsraum.de/datenraum"

# %%
session = Session(BASE_URL, Credentials(CLIENT_ID, CLIENT_SECRET))
client = Client(session)
source = client.create_source(slug="serlo", name="Serlo Education e.V.", organization="Serlo Education e.V.")

# %%
nodes = []

while True:
    new_nodes = source.get_nodes(offset=len(nodes))

    nodes.extend(new_nodes)

    if len(new_nodes) == 0:
        break

print(f"{len(nodes)} nodes downloaded from Datenraum of Serlo")
# Out:
# 8876 nodes downloaded from Datenraum of Serlo

# %% [markdown]
# # Check that `inLanguage == @language`

# %%
def language_is_inLanguage(node):
    amb = node["metadata"]["Amb"]
    language = [x for x in amb["@context"] if "@language" in x][0]["@language"]
    
    return amb["inLanguage"][0] == language

nodes_with_conflicting_language = [node for node in nodes[:10] if not language_is_inLanguage(node)]

if len(nodes_with_conflicting_language) == 0:
    print("✅ All Serlo nodes in Datenraum have `@language == inLanguage`")
else:
    print("❌ There are nodes in the Datenraum with `inLanguage != @language`")
    print(json.dumps(nodes_with_conflicting_language, indent=2))
# Out:
# ✅ All Serlo nodes in Datenraum have `@language == inLanguage`

# %% [markdown]
# # Check that all nodes have a description

# %%
import json

def has_description(node):
    amb = node["metadata"]["Amb"]
    
    return "description" in amb and amb["description"]

nodes_with_description = [node for node in nodes if not has_description(node)]


if len(nodes_with_description) == 0:
    print("✅ All Serlo nodes in Datenraum have a description")
else:
    print("❌ There are nodes in the Datenraum without a description")
    print(json.dumps(nodes_with_description, indent=2))
# Out:
# ❌ There are nodes in the Datenraum without a description
# [
#   {
#     "id": "f87233cc-743e-498a-8c1b-7230442b4b16",
#     "title": "\u00c1rea de un tri\u00e1ngulo",
#     "description": "",
#     "externalId": "https://serlo.org/261818",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/261818",
#         "name": "\u00c1rea de un tri\u00e1ngulo",
#         "type": [
#           "LearningResource",
#           "WebApplication"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1017",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/163773",
#             "name": "LinaMaria",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.es"
#         },
#         "version": {
#           "id": "https://serlo.org/262393"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "es"
#           }
#         ],
#         "headline": "\u00c1rea de un tri\u00e1ngulo",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/220145"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 261818,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "es"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2022-11-29T13:14:40+00:00",
#         "description": "",
#         "dateModified": "2022-12-06T12:29:30+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-16T00:08:52.850Z",
#             "dateModified": "2024-03-16T00:08:52.850Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/4665caac-99d7-4da3-b9fb-498d8ece034f"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/f87233cc-743e-498a-8c1b-7230442b4b16"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "60df726d-cd23-4c0e-9f2c-1943305a1ac0",
#     "title": "Aufgabe aus \"2022\"",
#     "description": "",
#     "externalId": "https://serlo.org/267014",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/267014",
#         "name": "Aufgabe aus \"2022\"",
#         "type": [
#           "LearningResource",
#           "Quiz"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1017",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/mathe.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/87602",
#             "name": "Karin",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           },
#           {
#             "id": "https://serlo.org/169563",
#             "name": "Peter",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.de"
#         },
#         "version": {
#           "id": "https://serlo.org/269626"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "de"
#           }
#         ],
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/266963"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 267014,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "de"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2023-02-03T16:03:34+00:00",
#         "description": "",
#         "dateModified": "2023-03-03T22:07:17+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-16T08:48:04.776Z",
#             "dateModified": "2024-03-16T08:48:04.776Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/a33ef73d-9210-4305-97f9-7357bbf43486"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/60df726d-cd23-4c0e-9f2c-1943305a1ac0"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "9e18dcc8-be9d-4726-8ed6-b48c9d7b11a3",
#     "title": "Aufgabe aus \"Aufgaben zu Gleichungen\"",
#     "description": "",
#     "externalId": "https://serlo.org/209269",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/209269",
#         "name": "Aufgabe aus \"Aufgaben zu Gleichungen\"",
#         "type": [
#           "LearningResource",
#           "Quiz"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1017",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/mathe.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/195445",
#             "name": "Anton_Zikmund",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.de"
#         },
#         "version": {
#           "id": "https://serlo.org/209273"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "de"
#           }
#         ],
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/40862"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 209269,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "de"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2021-05-07T09:22:30+00:00",
#         "description": "",
#         "dateModified": "2021-05-07T09:59:14+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T22:49:49.074Z",
#             "dateModified": "2024-03-15T22:49:49.074Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/a33ef73d-9210-4305-97f9-7357bbf43486"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/9e18dcc8-be9d-4726-8ed6-b48c9d7b11a3"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "4f804d69-8eb3-47e0-aca8-01b92f648882",
#     "title": "Aufgabe aus \"Aufgaben zum Ma\u00dfstab\"",
#     "description": "",
#     "externalId": "https://serlo.org/215119",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/215119",
#         "name": "Aufgabe aus \"Aufgaben zum Ma\u00dfstab\"",
#         "type": [
#           "LearningResource",
#           "Quiz"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1017",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/mathe.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/195445",
#             "name": "Anton_Zikmund",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.de"
#         },
#         "version": {
#           "id": "https://serlo.org/215122"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "de"
#           }
#         ],
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/34488"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 215119,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "de"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2021-06-14T09:34:42+00:00",
#         "description": "",
#         "dateModified": "2021-06-14T09:42:29+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T22:49:50.636Z",
#             "dateModified": "2024-03-15T22:49:50.636Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/a33ef73d-9210-4305-97f9-7357bbf43486"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/4f804d69-8eb3-47e0-aca8-01b92f648882"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "b02b25a6-0588-419d-a3fb-5a544b20ae3d",
#     "title": "Aufgabe aus \"\u00dcbungsaufgaben zum Thema Noten\"",
#     "description": "",
#     "externalId": "https://serlo.org/258587",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/258587",
#         "name": "Aufgabe aus \"\u00dcbungsaufgaben zum Thema Noten\"",
#         "type": [
#           "LearningResource",
#           "Quiz"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1020",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/145030",
#             "name": "Adrian_B",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           },
#           {
#             "id": "https://serlo.org/197401",
#             "name": "Annika-Hemlein",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.de"
#         },
#         "version": {
#           "id": "https://serlo.org/261962"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "de"
#           }
#         ],
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/235407"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 258587,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "de"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2022-10-08T13:23:24+00:00",
#         "description": "",
#         "dateModified": "2022-12-02T11:08:28+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-16T00:08:52.847Z",
#             "dateModified": "2024-03-16T00:08:52.847Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/a33ef73d-9210-4305-97f9-7357bbf43486"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/b02b25a6-0588-419d-a3fb-5a544b20ae3d"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "17817383-d2b7-482c-8f31-bf63c13be8c2",
#     "title": "Consent",
#     "description": "",
#     "externalId": "https://serlo.org/78326",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/78326",
#         "name": "Consent",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1029",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           },
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1001",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/31",
#             "name": "Hokkaidokuerbis",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/78328"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Consent",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/78340"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 78326,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2017-06-14T11:27:16+00:00",
#         "description": "",
#         "dateModified": "2017-06-14T11:28:30+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:11.714Z",
#             "dateModified": "2024-03-15T18:22:11.714Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/17817383-d2b7-482c-8f31-bf63c13be8c2"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "5dbf209a-65e3-4b8a-9fc6-ec3bf2e2e8fb",
#     "title": "Erweiterungskurs RFID und Bluetooth",
#     "description": "",
#     "externalId": "https://serlo.org/138934",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/138934",
#         "name": "Erweiterungskurs RFID und Bluetooth",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1013",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/informatik.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/129379",
#             "name": "opamp",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.de"
#         },
#         "version": {
#           "id": "https://serlo.org/138935"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "de"
#           }
#         ],
#         "headline": "Erweiterungskurs RFID und Bluetooth",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/129886"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 138934,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "de"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2019-06-14T19:43:03+00:00",
#         "description": "",
#         "dateModified": "2019-06-14T19:43:11+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:16.370Z",
#             "dateModified": "2024-03-15T18:22:16.370Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/5dbf209a-65e3-4b8a-9fc6-ec3bf2e2e8fb"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "08ec7c29-7407-47e4-87a8-f0ba13e2c886",
#     "title": "Exercise from \"\u0b87\u0bb2\u0b99\u0bcd\u0b95\u0bc8\u0b95\u0bcd\u0b95\u0bc1 \u0bb5\u0bb0\u0bc1\u0ba4\u0bb2\u0bcd \u0baa\u0baf\u0bbf\u0bb1\u0bcd\u0b9a\u0bbf \"",
#     "description": "",
#     "externalId": "https://serlo.org/159501",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/159501",
#         "name": "Exercise from \"\u0b87\u0bb2\u0b99\u0bcd\u0b95\u0bc8\u0b95\u0bcd\u0b95\u0bc1 \u0bb5\u0bb0\u0bc1\u0ba4\u0bb2\u0bcd \u0baa\u0baf\u0bbf\u0bb1\u0bcd\u0b9a\u0bbf \"",
#         "type": [
#           "LearningResource",
#           "Quiz"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1011",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/81950",
#             "name": "Menuja",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/159516"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "ta"
#           }
#         ],
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/152007"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 159501,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "ta"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2020-04-02T15:29:01+00:00",
#         "description": "",
#         "dateModified": "2020-04-02T15:57:11+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:17.309Z",
#             "dateModified": "2024-03-15T18:22:17.309Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/a33ef73d-9210-4305-97f9-7357bbf43486"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/08ec7c29-7407-47e4-87a8-f0ba13e2c886"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "207f8eca-2dac-4ec4-ae34-1cef932aabe5",
#     "title": "How to organize a team",
#     "description": "",
#     "externalId": "https://serlo.org/47391",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/47391",
#         "name": "How to organize a team",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/42113",
#             "name": "Benjamin",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/47392"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "How to organize a team",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/141120"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 47391,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2015-10-01T12:06:39+00:00",
#         "description": "",
#         "dateModified": "2015-10-01T12:06:50+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:10.505Z",
#             "dateModified": "2024-03-15T18:22:10.505Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/207f8eca-2dac-4ec4-ae34-1cef932aabe5"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "eff1a086-6944-44eb-8f3c-f97797fe3d83",
#     "title": "Interview with Serlo founder Simon K\u00f6hl ",
#     "description": "",
#     "externalId": "https://serlo.org/49568",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/49568",
#         "name": "Interview with Serlo founder Simon K\u00f6hl ",
#         "type": [
#           "LearningResource",
#           "VideoObject"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/10",
#             "name": "Simon",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/49569"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Interview with Serlo founder Simon K\u00f6hl ",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/49567"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 49568,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2015-12-01T22:00:33+00:00",
#         "description": "",
#         "dateModified": "2015-12-01T22:02:25+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:10.507Z",
#             "dateModified": "2024-03-15T18:22:10.507Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/7a6e9608-2554-4981-95dc-47ab9ba924de"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/eff1a086-6944-44eb-8f3c-f97797fe3d83"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "e767be10-5bf3-4225-9b82-b468303baba5",
#     "title": "Kick-Off",
#     "description": "",
#     "externalId": "https://serlo.org/43242",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/43242",
#         "name": "Kick-Off",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/42113",
#             "name": "Benjamin",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/43243"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Kick-Off",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/59628"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 43242,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2015-09-01T09:54:54+00:00",
#         "description": "",
#         "dateModified": "2015-09-01T09:55:04+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:09.123Z",
#             "dateModified": "2024-03-15T18:22:09.123Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/e767be10-5bf3-4225-9b82-b468303baba5"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "95a68299-240a-47e7-9b1d-003c48d34593",
#     "title": "Koordinatenform und Normalenform der Ebene",
#     "description": "",
#     "externalId": "https://serlo.org/106621",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/106621",
#         "name": "Koordinatenform und Normalenform der Ebene",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1017",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/mathe.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/105937",
#             "name": "MariusFriedemann",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.de"
#         },
#         "version": {
#           "id": "https://serlo.org/106622"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "de"
#           }
#         ],
#         "headline": "Koordinatenform und Normalenform der Ebene",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/1465"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 106621,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "de"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2018-05-19T19:07:46+00:00",
#         "description": "",
#         "dateModified": "2018-05-19T19:08:11+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:13.873Z",
#             "dateModified": "2024-03-15T18:22:13.873Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/95a68299-240a-47e7-9b1d-003c48d34593"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "fb980765-b7b9-4752-ad1e-754ff7ddb13c",
#     "title": "Normalenform und Koordinatenform der Ebene",
#     "description": "",
#     "externalId": "https://serlo.org/106007",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/106007",
#         "name": "Normalenform und Koordinatenform der Ebene",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1017",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/mathe.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/105937",
#             "name": "MariusFriedemann",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.de"
#         },
#         "version": {
#           "id": "https://serlo.org/106008"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "de"
#           }
#         ],
#         "headline": "Normalenform und Koordinatenform der Ebene",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/1465"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 106007,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "de"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2018-05-13T12:48:49+00:00",
#         "description": "",
#         "dateModified": "2018-05-13T12:49:14+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:13.872Z",
#             "dateModified": "2024-03-15T18:22:13.872Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/fb980765-b7b9-4752-ad1e-754ff7ddb13c"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "17b8dd5e-731b-4d25-afff-32a0483794e9",
#     "title": "Octave",
#     "description": "",
#     "externalId": "https://serlo.org/60694",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/60694",
#         "name": "Octave",
#         "type": [
#           "LearningResource",
#           "Article"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/52732",
#             "name": "dominiklechner",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/60695"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Octave",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/50411"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 60694,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2016-08-05T15:44:00+00:00",
#         "description": "",
#         "dateModified": "2016-08-05T15:44:17+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:10.517Z",
#             "dateModified": "2024-03-15T18:22:10.517Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/588efe4f-976f-48eb-84aa-8bcb45679f85"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/17b8dd5e-731b-4d25-afff-32a0483794e9"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "88bdc986-d0ba-4ead-9f32-3e9000852650",
#     "title": "Seventh",
#     "description": "",
#     "externalId": "https://serlo.org/60692",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/60692",
#         "name": "Seventh",
#         "type": [
#           "LearningResource",
#           "Article"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/52732",
#             "name": "dominiklechner",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/60693"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Seventh",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/50411"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 60692,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2016-08-05T15:43:31+00:00",
#         "description": "",
#         "dateModified": "2016-08-05T15:43:48+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:10.517Z",
# ...
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "c3f7ba30-1be1-4699-b894-603faa94b05e",
#     "title": "Stage 1:  Preparation",
#     "description": "",
#     "externalId": "https://serlo.org/46939",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/46939",
#         "name": "Stage 1:  Preparation",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/42113",
#             "name": "Benjamin",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/46941"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Stage 1:  Preparation",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/48622"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 46939,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2015-09-25T13:07:32+00:00",
#         "description": "",
#         "dateModified": "2015-09-25T13:08:50+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:10.504Z",
#             "dateModified": "2024-03-15T18:22:10.504Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/c3f7ba30-1be1-4699-b894-603faa94b05e"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "08742549-5263-440b-bccc-20d0ff0d78ae",
#     "title": "Stage 2: Growths ",
#     "description": "",
#     "externalId": "https://serlo.org/47283",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/47283",
#         "name": "Stage 2: Growths ",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/42113",
#             "name": "Benjamin",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/47779"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Stage 2: Growths ",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/48622"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 47283,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2015-09-30T14:16:44+00:00",
#         "description": "",
#         "dateModified": "2015-10-08T10:59:23+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:10.505Z",
#             "dateModified": "2024-03-15T18:22:10.505Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/08742549-5263-440b-bccc-20d0ff0d78ae"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "62a052d4-6c4a-4658-9d62-7320a04492a1",
#     "title": "Stage 3: Professionalization",
#     "description": "",
#     "externalId": "https://serlo.org/108067",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/108067",
#         "name": "Stage 3: Professionalization",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/10",
#             "name": "Simon",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/108068"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Stage 3: Professionalization",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/48622"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 108067,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2018-06-01T14:39:17+00:00",
#         "description": "",
#         "dateModified": "2018-06-01T14:40:07+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:13.875Z",
#             "dateModified": "2024-03-15T18:22:13.875Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/62a052d4-6c4a-4658-9d62-7320a04492a1"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "3f086271-bf47-452f-87d7-52d7a58ff418",
#     "title": "Upcycling von Kleidung",
#     "description": "",
#     "externalId": "https://serlo.org/108472",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/108472",
#         "name": "Upcycling von Kleidung",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "about": [
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1001",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           },
#           {
#             "id": "http://w3id.org/kim/schulfaecher/s1008",
#             "type": "Concept",
#             "inScheme": {
#               "id": "http://w3id.org/kim/schulfaecher/"
#             }
#           }
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/nachhaltigkeit.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/105102",
#             "name": "Annka_Bremer",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           },
#           {
#             "id": "https://serlo.org/27693",
#             "name": "Nish",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/deed.de"
#         },
#         "version": {
#           "id": "https://serlo.org/108638"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "de"
#           }
#         ],
#         "headline": "Upcycling von Kleidung",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/102788"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 108472,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "de"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2018-06-11T11:10:37+00:00",
#         "description": "",
#         "dateModified": "2018-06-12T10:30:37+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:13.875Z",
#             "dateModified": "2024-03-15T18:22:13.875Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/3f086271-bf47-452f-87d7-52d7a58ff418"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   },
#   {
#     "id": "b29404f0-3d2d-4c46-a444-0e3b4a97b336",
#     "title": "Use the watering can - public relations",
#     "description": "",
#     "externalId": "https://serlo.org/44490",
#     "sourceId": "d8f481cb-3be6-4a91-9f5b-c22b35b918ae",
#     "metadata": {
#       "Amb": {
#         "id": "https://serlo.org/44490",
#         "name": "Use the watering can - public relations",
#         "type": [
#           "LearningResource",
#           "Course"
#         ],
#         "image": "https://de.serlo.org/_assets/img/meta/serlo.png",
#         "creator": [
#           {
#             "id": "https://serlo.org/42113",
#             "name": "Benjamin",
#             "type": "Person",
#             "affiliation": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             }
#           }
#         ],
#         "license": {
#           "id": "https://creativecommons.org/licenses/by-sa/4.0/"
#         },
#         "version": {
#           "id": "https://serlo.org/47508"
#         },
#         "@context": [
#           "https://w3id.org/kim/amb/context.jsonld",
#           "https://schema.org",
#           {
#             "@language": "en"
#           }
#         ],
#         "headline": "Use the watering can - public relations",
#         "isPartOf": [
#           {
#             "id": "https://serlo.org/141092"
#           }
#         ],
#         "publisher": [
#           {
#             "id": "https://serlo.org/organization",
#             "name": "Serlo Education e.V.",
#             "type": "Organization"
#           }
#         ],
#         "identifier": {
#           "type": "PropertyValue",
#           "value": 44490,
#           "propertyID": "UUID"
#         },
#         "inLanguage": [
#           "en"
#         ],
#         "maintainer": {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         },
#         "dateCreated": "2015-09-08T10:10:38+00:00",
#         "description": "",
#         "dateModified": "2015-10-02T08:45:48+00:00",
#         "isFamilyFriendly": true,
#         "mainEntityOfPage": [
#           {
#             "id": "https://serlo.org/metadata",
#             "type": "WebContent",
#             "provider": {
#               "id": "https://serlo.org/organization",
#               "name": "Serlo Education e.V.",
#               "type": "Organization"
#             },
#             "dateCreated": "2024-03-15T18:22:09.125Z",
#             "dateModified": "2024-03-15T18:22:09.125Z"
#           }
#         ],
#         "isAccessibleForFree": true,
#         "learningResourceType": [
#           {
#             "id": "http://w3id.org/openeduhub/vocabs/new_lrt/ad9b9299-0913-40fb-8ad3-50c5fd367b6a"
#           }
#         ]
#       }
#     },
#     "class": "LearningOpportunity",
#     "min": 0,
#     "max": null,
#     "_embedded": null,
#     "_links": {
#       "self": {
#         "href": "https://dam.demo.meinbildungsraum.de/datenraum/api/core/nodes/b29404f0-3d2d-4c46-a444-0e3b4a97b336"
#       },
#       "headNodes": null,
#       "tailNodes": null,
#       "childNodes": null
#     }
#   }
# ]
