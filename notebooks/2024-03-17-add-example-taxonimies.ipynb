# %% [markdown]
# # Basic variables

# %%
from getpass import getpass

CLIENT_ID = getpass("CLIENT_ID: ")
CLIENT_SECRET = getpass("CLIENT_SECRET: ")
# Out:
# CLIENT_ID:  ········
# CLIENT_SECRET:  ········

# %% [markdown]
# # Initialize client for Datenraum

# %%
import sys
import os

sys.path.append(os.path.join(os.getcwd(), '..'))

from datenraum import *

session = Session(Environment.DEV, Credentials(CLIENT_ID, CLIENT_SECRET))
client = Client(session)
source = client.create_source(slug="serlo", name="Serlo Education e.V.", organization="Serlo Education e.V.")

# %% [markdown]
# # Example taxonomies

# %%
BIG_DATA_TAXONOMY = {
    "about": [
        {
            "type": "Concept",
            "id": "http://w3id.org/kim/schulfaecher/s1013",
            "inScheme": {"id": "http://w3id.org/kim/schulfaecher/"},
        }
    ],
    "@context": [
        "https://w3id.org/kim/amb/context.jsonld",
        "https://schema.org",
    ],
    "dateCreated": "2020-03-17T09:33:15",
    "dateModified": "2020-04-30T07:48:36",
    "creator": [
        {
            "type": "Person",
            "id": "https://serlo.org/18981",
            "name": "wolfgang",
        }
    ],
    "description": """In diesem Themenbereich auf Serlo findest du drei kurze Artikel,
     die den Begriff „Big Data“ einfach und anschaulich erklären –
      die Links dazu findest du unten, am Ende der Einleitung. Viel Spaß!""",
    "headline": "Big Data – einfach erklärt",
    "id": "https://serlo.org/155948",
    "identifier": {"propertyID": "UUID", "type": "PropertyValue", "value": 155948},
    "image": "https://assets.serlo.org/5e6d30a60f21a_33bd694cc1e54c7be4a3363277ce1aeec8c5d0c0.jpg",
    "inLanguage": ["de"],
    "isAccessibleForFree": True,
    "isFamilyFriendly": True,
    "maintainer": {
        "id": "https://serlo.org/organization",
        "name": "Serlo Education e.V.",
        "type": "Organization",
    },
    "name": "Big Data – einfach erklärt",
    "publisher": [
        {
            "id": "https://serlo.org/organization",
            "name": "Serlo Education e.V.",
            "type": "Organization",
        }
    ],
    "type": ["LearningResource"],
}

GAME_THEORY_TAXONOMY = {
    "about": [
        {
            "type": "Concept",
            "id": "http://w3id.org/kim/schulfaecher/s1013",
            "inScheme": {"id": "http://w3id.org/kim/schulfaecher/"},
        }
    ],
    "@context": [
        "https://w3id.org/kim/amb/context.jsonld",
        "https://schema.org",
    ],
    "dateCreated": "2021-02-04T20:08:55",
    "dateModified": "2021-02-04T20:13:40",
    "creator": [
        {
            "type": "Person",
            "id": "https://serlo.org/18981",
            "name": "wolfgang",
        }
    ],
    "description": """Spieltheorie ist eine mathematische Disziplin,
     die das rationale Verhalten von Entscheidungsträgern in interaktiven Situationen analysiert,
      in denen die Ergebnisse von den Entscheidungen anderer abhängen.""",
    "headline": "Spieltheorie",
    "id": "https://serlo.org/192971",
    "identifier": {"propertyID": "UUID", "type": "PropertyValue", "value": 192971},
    "image": "https://assets.serlo.org/5e6d30a60f21a_33bd694cc1e54c7be4a3363277ce1aeec8c5d0c0.jpg",
    "inLanguage": ["de"],
    "isAccessibleForFree": True,
    "isFamilyFriendly": True,
    "maintainer": {
        "id": "https://serlo.org/organization",
        "name": "Serlo Education e.V.",
        "type": "Organization",
    },
    "name": "Spieltheorie",
    "publisher": [
        {
            "id": "https://serlo.org/organization",
            "name": "Serlo Education e.V.",
            "type": "Organization",
        }
    ],
    "type": ["LearningResource"],
}

taxonomies = [BIG_DATA_TAXONOMY, GAME_THEORY_TAXONOMY]

# %% [markdown]
# # Add/update taxonomies to Datenraum

# %%
for node in taxonomies:
    datenraum_node = source.get_node_from_external_id(node["id"])
    
    if datenraum_node is None:
        source.add_node(node)
    else:
        source.update_node(node, datenraum_node["id"])

# %% [markdown]
# # Show added nodes of the taxonomies in the Datenraum

# %%
import json

for node in taxonomies:
    node_id = node["id"]
    datenraum_node = source.get_node_from_external_id(node_id)
    
    if datenraum_node is not None:
        datenraum_node_id = datenraum_node["id"]
        
        print(f"### Node {datenraum_node_id} for {node_id}")
        print()
        print(json.dumps(datenraum_node, indent=2))
        print()
        print()
    else:
        print("ERROR: {node_id} was not added to Datenraum")
# Out:
# ### Node fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7 for https://serlo.org/155948
#
# {
#   "id": "fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7",
#   "title": "Big Data \u2013 einfach erkl\u00e4rt",
#   "description": "In diesem Themenbereich auf Serlo findest du drei kurze Artikel,\n     die den Begriff \u201eBig Data\u201c einfach und anschaulich erkl\u00e4ren \u2013\n      die Links dazu findest du unten, am Ende der Einleitung. Viel Spa\u00df!",
#   "externalId": "https://serlo.org/155948",
#   "sourceId": "dba27e08-0f8c-4bc1-aaa9-9f3ae0868f90",
#   "metadata": {
#     "Amb": {
#       "id": "https://serlo.org/155948",
#       "name": "Big Data \u2013 einfach erkl\u00e4rt",
#       "type": [
#         "LearningResource"
#       ],
#       "about": [
#         {
#           "id": "http://w3id.org/kim/schulfaecher/s1013",
#           "type": "Concept",
#           "inScheme": {
#             "id": "http://w3id.org/kim/schulfaecher/"
#           }
#         }
#       ],
#       "image": "https://assets.serlo.org/5e6d30a60f21a_33bd694cc1e54c7be4a3363277ce1aeec8c5d0c0.jpg",
#       "creator": [
#         {
#           "id": "https://serlo.org/18981",
#           "name": "wolfgang",
#           "type": "Person"
#         }
#       ],
#       "@context": [
#         "https://w3id.org/kim/amb/context.jsonld",
#         "https://schema.org",
#         {
#           "@language": "de"
#         }
#       ],
#       "headline": "Big Data \u2013 einfach erkl\u00e4rt",
#       "publisher": [
#         {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         }
#       ],
#       "identifier": {
#         "type": "PropertyValue",
#         "value": 155948,
#         "propertyID": "UUID"
#       },
#       "inLanguage": [
#         "de"
#       ],
#       "maintainer": {
#         "id": "https://serlo.org/organization",
#         "name": "Serlo Education e.V.",
#         "type": "Organization"
#       },
#       "dateCreated": "2020-03-17T09:33:15",
#       "description": "In diesem Themenbereich auf Serlo findest du drei kurze Artikel,\n     die den Begriff \u201eBig Data\u201c einfach und anschaulich erkl\u00e4ren \u2013\n      die Links dazu findest du unten, am Ende der Einleitung. Viel Spa\u00df!",
#       "dateModified": "2020-04-30T07:48:36",
#       "isFamilyFriendly": true,
#       "isAccessibleForFree": true
#     }
#   },
#   "class": "LearningOpportunity",
#   "_embedded": {
#     "headEdges": [],
#     "tailEdges": []
#   },
#   "_links": {
#     "self": {
#       "href": "https://dam-dev.nbpdev.de/datenraum/api/core/nodes/fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7"
#     },
#     "headNodes": [],
#     "tailNodes": [],
#     "childNodes": null
#   }
# }
#
#
# ### Node 7c922a02-051f-4960-bf0b-d14e84dbefe8 for https://serlo.org/192971
#
# {
#   "id": "7c922a02-051f-4960-bf0b-d14e84dbefe8",
#   "title": "Spieltheorie",
#   "description": "Spieltheorie ist eine mathematische Disziplin,\n     die das rationale Verhalten von Entscheidungstr\u00e4gern in interaktiven Situationen analysiert,\n      in denen die Ergebnisse von den Entscheidungen anderer abh\u00e4ngen.",
#   "externalId": "https://serlo.org/192971",
#   "sourceId": "dba27e08-0f8c-4bc1-aaa9-9f3ae0868f90",
#   "metadata": {
#     "Amb": {
#       "id": "https://serlo.org/192971",
#       "name": "Spieltheorie",
#       "type": [
#         "LearningResource"
#       ],
#       "about": [
#         {
#           "id": "http://w3id.org/kim/schulfaecher/s1013",
#           "type": "Concept",
#           "inScheme": {
#             "id": "http://w3id.org/kim/schulfaecher/"
#           }
#         }
#       ],
#       "image": "https://assets.serlo.org/5e6d30a60f21a_33bd694cc1e54c7be4a3363277ce1aeec8c5d0c0.jpg",
#       "creator": [
#         {
#           "id": "https://serlo.org/18981",
#           "name": "wolfgang",
#           "type": "Person"
#         }
#       ],
#       "@context": [
#         "https://w3id.org/kim/amb/context.jsonld",
#         "https://schema.org",
#         {
#           "@language": "de"
#         }
#       ],
#       "headline": "Spieltheorie",
#       "publisher": [
#         {
#           "id": "https://serlo.org/organization",
#           "name": "Serlo Education e.V.",
#           "type": "Organization"
#         }
#       ],
#       "identifier": {
#         "type": "PropertyValue",
#         "value": 192971,
#         "propertyID": "UUID"
#       },
#       "inLanguage": [
#         "de"
#       ],
#       "maintainer": {
#         "id": "https://serlo.org/organization",
#         "name": "Serlo Education e.V.",
#         "type": "Organization"
#       },
#       "dateCreated": "2021-02-04T20:08:55",
#       "description": "Spieltheorie ist eine mathematische Disziplin,\n     die das rationale Verhalten von Entscheidungstr\u00e4gern in interaktiven Situationen analysiert,\n      in denen die Ergebnisse von den Entscheidungen anderer abh\u00e4ngen.",
#       "dateModified": "2021-02-04T20:13:40",
#       "isFamilyFriendly": true,
#       "isAccessibleForFree": true
#     }
#   },
#   "class": "LearningOpportunity",
#   "_embedded": {
#     "headEdges": [],
#     "tailEdges": []
#   },
#   "_links": {
#     "self": {
#       "href": "https://dam-dev.nbpdev.de/datenraum/api/core/nodes/7c922a02-051f-4960-bf0b-d14e84dbefe8"
#     },
#     "headNodes": [],
#     "tailNodes": [],
#     "childNodes": null
#   }
# }

# %% [markdown]
# # Load all Datenraum nodes of Serlo

# %%
serlo_nodes = []

while True:
    new_nodes = source.get_nodes(offset=len(serlo_nodes))

    serlo_nodes.extend(new_nodes)

    if len(new_nodes) == 0:
        break

print(f"{len(serlo_nodes)} nodes downloaded from Datenraum of Serlo")
# Out:
# 8855 nodes downloaded from Datenraum of Serlo

# %% [markdown]
# # Show current edge types

# %%
print(json.dumps(source.get_edge_types(), indent=2))
# Out:
# {
#   "total": 13,
#   "offset": 0,
#   "limit": 10,
#   "_embedded": {
#     "edgeTypes": [
#       {
#         "id": "287215a2-4952-49f1-99d9-01f9ff3e62aa",
#         "name": "teaches",
#         "description": "the node teaches given skills / competencies",
#         "slug": "teaches",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/287215a2-4952-49f1-99d9-01f9ff3e62aa"
#           }
#         }
#       },
#       {
#         "id": "328ed6c0-d30e-4724-8713-e1331f6efa4e",
#         "name": "optional",
#         "description": "optional skill for this occupation",
#         "slug": "optional",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/328ed6c0-d30e-4724-8713-e1331f6efa4e"
#           }
#         }
#       },
#       {
#         "id": "3d69bf99-efba-4295-bcab-c37ba616b6b5",
#         "name": "taught by",
#         "description": "ESCO skill is taught by LO",
#         "slug": "dev-9591-taught-by",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/3d69bf99-efba-4295-bcab-c37ba616b6b5"
#           }
#         }
#       },
#       {
#         "id": "4c2b4d70-151b-400f-868b-cc8e0e34d9f9",
#         "name": "is in category",
#         "description": "Belongs to a category given by an other source",
#         "slug": "in-category",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/4c2b4d70-151b-400f-868b-cc8e0e34d9f9"
#           }
#         }
#       },
#       {
#         "id": "79aac178-a06d-4eee-a1b4-4ed34a67e3f8",
#         "name": "narrower",
#         "description": "narrower occupation or skill",
#         "slug": "narrower",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/79aac178-a06d-4eee-a1b4-4ed34a67e3f8"
#           }
#         }
#       },
#       {
#         "id": "7a84ef44-c04e-49cd-b602-44ffd98de354",
#         "name": "req",
#         "description": "occupation optionally requires skill",
#         "slug": "occ-req-opt",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/7a84ef44-c04e-49cd-b602-44ffd98de354"
#           }
#         }
#       },
#       {
#         "id": "9703605d-9b1c-43a3-889f-f3eaeb2bf583",
#         "name": "teaches",
#         "description": "curriculum teaches skill",
#         "slug": "cur-teach",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/9703605d-9b1c-43a3-889f-f3eaeb2bf583"
#           }
#         }
#       },
#       {
#         "id": "9828be96-c9b6-4e02-8d9b-cb091509915f",
#         "name": "competency required",
#         "description": "a given competency is required for this node",
#         "slug": "competencyRequired",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/9828be96-c9b6-4e02-8d9b-cb091509915f"
#           }
#         }
#       },
#       {
#         "id": "b0b05388-6e02-4465-b5f0-cd7e7f8695b0",
#         "name": "teaches",
#         "description": "LO teaches ESCO skill",
#         "slug": "dev-9591-teaches",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/b0b05388-6e02-4465-b5f0-cd7e7f8695b0"
#           }
#         }
#       },
#       {
#         "id": "cdaf6c15-e307-403c-b9ee-d13dbad8a68f",
#         "name": "Child of",
#         "description": "[from] is child of [to]",
#         "slug": "childOf",
#         "_links": {
#           "self": {
#             "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types/cdaf6c15-e307-403c-b9ee-d13dbad8a68f"
#           }
#         }
#       }
#     ]
#   },
#   "_links": {
#     "self": {
#       "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types?Offset=0&Limit=10"
#     },
#     "next": {
#       "href": "https://dam-dev.nbpdev.de/datenraum/api/core/edge-types?Offset=10&Limit=10"
#     }
#   }
# }

# %% [markdown]
# # Used edge typoe

# %%
edge_type_id = "cdaf6c15-e307-403c-b9ee-d13dbad8a68f"

# %% [markdown]
# # Add edges of taxonomies to learning oppurtunities into the Datenraum

# %%
def is_child(datenraum_node, taxonomy_id):
    try:
        parents = datenraum_node["metadata"]["Amb"]["isPartOf"]
    
        return any(parent["id"] == taxonomy_id for parent in parents)
    except KeyError:
        return False
    

for taxonomy in taxonomies:
    taxonomy_id = taxonomy["id"]
    datenraum_taxonomy = source.get_node_from_external_id(taxonomy_id)
    children = [child for child in serlo_nodes if is_child(child, taxonomy_id)]
    
    for child in children:
        child_id = child["id"]
        datenraum_taxonomy_id = datenraum_taxonomy["id"]
        source.add_edge(edge_type_id, child_id, datenraum_taxonomy_id)
    
        print(f"Add edge: {child_id} is Part of {datenraum_taxonomy_id}")
# Out:
# Add edge: a0611974-9ecd-4e4d-a88e-ec4c612ea6fd is Part of fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7
# Add edge: 16939942-ed88-4572-b5e8-4cd7d34ab123 is Part of fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7
# Add edge: c7f6f142-7fc4-4ca9-b877-7ff5bffa197c is Part of fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7
# Add edge: a8b41c4a-c904-42bb-ad3a-fde06c7c4eac is Part of fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7
# Add edge: a076fe8b-f86e-4423-9185-dbe36284d4d7 is Part of fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7
# Add edge: 01c5c572-e6bd-4c7b-826c-44dd651430a4 is Part of fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7
# Add edge: b75744f7-67a3-43dc-b620-a2c21d88ec43 is Part of fad9e7d0-eb2a-4e96-9fce-c1d4917a2ca7
# Add edge: 1c3927b6-8f21-4045-b736-94d1915bb932 is Part of 7c922a02-051f-4960-bf0b-d14e84dbefe8
# Add edge: 5f133770-c7f8-4d46-be68-01f663eb7701 is Part of 7c922a02-051f-4960-bf0b-d14e84dbefe8
# Add edge: 23aa2cf0-d130-4590-8e90-b5cac01ac710 is Part of 7c922a02-051f-4960-bf0b-d14e84dbefe8
# Add edge: e959b059-32c2-41b2-8ffd-960acb0f208b is Part of 7c922a02-051f-4960-bf0b-d14e84dbefe8
# Add edge: a70b40ab-b82e-42c8-864c-8663d71978d4 is Part of 7c922a02-051f-4960-bf0b-d14e84dbefe8
